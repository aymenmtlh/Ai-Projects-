# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch

results = model.train(data="config.yaml", epochs=1)  # train the model
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
import cv2
import os 
from ultralytics import YOLO
import cv2

cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    H, W, _ = frame.shape
    model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')
    model = YOLO(model_path)
    threshold = 0.5
    while ret:

        results = model(frame)[0]

        for result in results.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = result

            if score > threshold:
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
                cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                              cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)
                
    
    

    cv2.imshow("Image", frame)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break

        
cap.realese()        
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 197.2ms
# Speed: 3.0ms preprocess, 197.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 184.2ms
# Speed: 4.0ms preprocess, 184.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 175.1ms
# Speed: 3.5ms preprocess, 175.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 175.5ms
# Speed: 3.0ms preprocess, 175.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 165.5ms
# Speed: 3.0ms preprocess, 165.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 193.7ms
# Speed: 3.0ms preprocess, 193.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 183.5ms
# Speed: 4.0ms preprocess, 183.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# ...

# %%
import os 
from ultralytics import YOLO
import cv2
model_path = os.path.join('.', 'runs', 'detect', 'train', 'weights', 'last.pt')
model = YOLO(model_path)

# %%
# !yolo predict model=model source 0
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Shift-Tech\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\Shift-Tech\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Shift-Tech\anaconda3\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\Shift-Tech\anaconda3\lib\site-packages\ultralytics\cfg\__init__.py", line 379, in entrypoint
#     raise SyntaxError(f"'{colorstr('red', 'bold', a)}' is a valid YOLO argument but is missing an '=' sign "
# SyntaxError: 'source' is a valid YOLO argument but is missing an '=' sign to set its value, i.e. try 'source=None'
#
#     Arguments received: ['yolo', 'predict', 'model=model', 'source', '0']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
# ...

# %%
from ultralytics import YOLO
from ultralytics.yolo.v8.detect.predict import DetectionPredictor
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.

# %%
model = YOLO("yolov8s.pt")
pred = model.predict(source ="0" , show = True)

for r in pred : 
    boxes =  r.boxes
    
    for a in boxes :
        for index , name in r.names.items() :
            
            
            if a.cls == index : 
                print (name  , 'detected ')
            else : 
                print('no ' , name )
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 (no detections), 494.1ms
# 0: 480x640 1 person, 459.0ms
# 0: 480x640 1 person, 506.8ms
# 0: 480x640 1 person, 426.3ms
# 0: 480x640 1 person, 431.3ms
# 0: 480x640 1 person, 429.8ms
# 0: 480x640 1 person, 443.6ms
# 0: 480x640 1 person, 507.6ms
# 0: 480x640 1 person, 437.1ms
# 0: 480x640 1 person, 453.1ms
# 0: 480x640 1 person, 439.0ms
# ...

# %%
from ultralytics import YOLO
from ultralytics.yolo.v8.detect.predict import DetectionPredictor
# Out:
# WARNING  'ultralytics.yolo.v8' is deprecated since '8.0.136' and will be removed in '8.1.0'. Please use 'ultralytics.models.yolo' instead.

# %%
model = YOLO("yolov8s.pt")
pred = model.predict(source = 'mine.jpg' , show = True)
print(pred)
# Out:
# image 1/1 C:\Users\Shift-Tech\Desktop\yolo\mine.jpg: 640x448 2 persons, 337.3ms
# Speed: 3.5ms preprocess, 337.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# ...

# %%
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5m, yolov5l, yolov5x, custom

# Images
img = 'https://ultralytics.com/images/zidane.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
if 'your class' in results.pandas().xyxy[0]['name'].tolist(): 
    set_alarm() # your function
# Out:
# Using cache found in C:\Users\Shift-Tech/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-4-13 Python-3.9.12 torch-1.13.1+cpu CPU
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
